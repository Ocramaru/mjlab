# %%
from mjlab import MJLAB_SRC_PATH

# %%
base_path = MJLAB_SRC_PATH
robots_path = base_path / "asset_zoo" / "robots"

# %%
print(base_path)
print(robots_path)
# Out:
# /home/marcocassar/workspace/projects/ml/mjlab/src/mjlab
# /home/marcocassar/workspace/projects/ml/mjlab/src/mjlab/asset_zoo/robots
