# %% [markdown]
# <a href="https://colab.research.google.com/github/mujocolab/mjlab/blob/main/notebooks/create_new_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🤖 CartPole Tutorial with mjlab**
#
# This notebook demonstrates how to create a custom reinforcement learning task using mjlab. We'll build a CartPole environment from scratch, including:
#
# 1. **Robot Definition** - Define the CartPole model in MuJoCo XML
# 2. **Task Configuration** - Set up observations, actions, rewards, and terminations
# 3. **Training** - Train a policy using PPO
# 4. **Evaluation** - Visualize the simulation with the trained policy
#
# > **Note**: This tutorial demonstrates how to create a new task in mjlab. For more context, see the [official documentation](https://mujocolab.github.io/mjlab/).

# %% [markdown]
# ---
#
# ## **🤖 Step 1: Define the Robot**
#
# We'll create a simple CartPole robot with:
# - A sliding cart (1 DOF)
# - A hinged pole (1 DOF)
# - A velocity actuator to control the cart

# %% [markdown]
# ### **📁 Structure Directories**

# %%
base_dir = "../src/mjlab/asset_zoo/robots/cartpole/"

# %%
# Create the cartpole robot directory structure
# !mkdir -p ../src/mjlab/asset_zoo/robots/cartpole/
# !mkdir -p ../src/mjlab/asset_zoo/robots/cartpole/xmls

print("✓ Directory structure created")
# Out:
# ✓ Directory structure created

# %% [markdown]
# ### **📝 Create MuJoCo XML Model**
#
# This XML defines the CartPole physics:
# - **Ground plane** for visualization
# - **Cart body** with a sliding joint (±2m range)
# - **Pole body** with a hinge joint (±90° range)
# - **Velocity actuator** for cart control

# %%
# %%writefile ../src/mjlab/asset_zoo/robots/cartpole/xmls/cartpole.xml
# <mujoco model="cartpole">
#   <compiler angle="degree" coordinate="local" inertiafromgeom="true"/>
#   <worldbody>
#     <geom name="ground" type="plane" pos="0 0 0" size="5 5 0.1" rgba="0.8 0.9 0.8 1"/>
#     <body name="cart" pos="0 0 0.1">
#       <geom type="box" size="0.2 0.1 0.1" rgba="0.2 0.2 0.8 1" mass="1.0"/>
#       <joint name="slide" type="slide" axis="1 0 0" limited="true" range="-2 2"/>
#       <body name="pole" pos="0 0 0.1">
#         <geom type="capsule" size="0.05 0.5" fromto="0 0 0 0 0 1" rgba="0.8 0.2 0.2 1" mass="2.0"/>
#         <joint name="hinge" type="hinge" axis="0 1 0" range="-90 90"/>
#       </body>
#     </body>
#   </worldbody>
#   <actuator>
#     <velocity name="slide_velocity" joint="slide" ctrlrange="-20 20" kv="20"/>
#   </actuator>
# </mujoco>
# Out:
# Overwriting ../src/mjlab/asset_zoo/robots/cartpole/xmls/cartpole.xml

# %% [markdown]
# ### **⚙️ Create Robot Configuration**

# %%
# %%writefile ../src/mjlab/asset_zoo/robots/cartpole/cartpole_constants.py
from pathlib import Path
import mujoco

from mjlab import MJLAB_SRC_PATH
from mjlab.entity import Entity, EntityCfg, EntityArticulationInfoCfg
from mjlab.actuator import XmlActuatorCfg

CARTPOLE_XML: Path = (
  MJLAB_SRC_PATH / "asset_zoo" / "robots" / "cartpole" / "xmls" / "cartpole.xml"
)
assert CARTPOLE_XML.exists(), f"XML not found: {CARTPOLE_XML}"

def get_spec() -> mujoco.MjSpec:
  return mujoco.MjSpec.from_file(str(CARTPOLE_XML))

def get_cartpole_robot_cfg() -> EntityCfg:
  """Get a fresh CartPole robot configuration instance."""
  actuators = (
    XmlActuatorCfg(
      target_names_expr=("slide",),
    ),
  )
  articulation = EntityArticulationInfoCfg(actuators=actuators)
  return EntityCfg(
    spec_fn=get_spec,
    articulation=articulation
  )

# if __name__ == "__main__":
#   import mujoco.viewer as viewer
#   robot = Entity(get_cartpole_robot_cfg())
#   viewer.launch(robot.spec.compile())
# Out:
# Overwriting ../src/mjlab/asset_zoo/robots/cartpole/cartpole_constants.py

# %%
# Create __init__.py for the cartpole robot package
# !touch ../src/mjlab/asset_zoo/robots/cartpole/__init__.py
# Empty __init__.py to mark the directory as a Python package

# %%
import sys

# Append src dir to python path
mjlab_src = "../src"
if mjlab_src not in sys.path:
  sys.path.insert(0, mjlab_src)
  print(f"✓ Added {mjlab_src} to Python path")
# Out:
# ✓ Added ../src to Python path

# %% [markdown]
# ### **✅ Verify Robot Setup**
#
# Let's test that the robot can be loaded correctly.

# %%
from mjlab.asset_zoo.robots.cartpole.cartpole_constants import get_cartpole_robot_cfg
from mjlab.entity import Entity

# Load the robot
robot = Entity(get_cartpole_robot_cfg())
model = robot.spec.compile()

# Display robot information
print("✓ CartPole robot loaded successfully!")
print(f"  • Degrees of Freedom (DOF): {model.nv}")
print(f"  • Number of Actuators: {model.nu}")
print(f"  • Bodies: {model.nbody}")
print(f"  • Joints: {model.njnt}")
# Out:
# ✓ CartPole robot loaded successfully!
#   • Degrees of Freedom (DOF): 2
#   • Number of Actuators: 1
#   • Bodies: 4
#   • Joints: 2

# %% [markdown]
# ### **📋 Register the Robot**
#
# Add the CartPole robot to the asset zoo registry.

# %%
# Add CartPole import to robots __init__.py
with open("../src/mjlab/asset_zoo/robots/__init__.py", "a") as f:
  f.write("\n# CartPole robot\n")
  f.write("from mjlab.asset_zoo.robots.cartpole.cartpole_constants import ")
  f.write("get_cartpole_robot_cfg as get_cartpole_robot_cfg\n")

print("✓ CartPole robot registered in asset zoo")
# Out:
# ✓ CartPole robot registered in asset zoo

# %% [markdown]
# ---
#
# ## **🎯 Step 2: Define the Task (MDP)**
#
# Now we'll define the Markov Decision Process:
# - **Observations**: pole angle, angular velocity, cart position, cart velocity
# - **Actions**: cart velocity commands
# - **Rewards**: upright reward + effort penalty
# - **Terminations**: pole tips over or timeout
# - **Events**: random pushes for robustness

# %% [markdown]
# ### **📁 Create Task Directory**

# %%
# !mkdir -p ../src/mjlab/tasks/cartpole

print("✓ Task directory created")
# Out:
# ✓ Task directory created

# %% [markdown]
# ### **📝 Create Environment Configuration**
#
# This file contains the MDP (Markov Decision Process) components:
# 1. **Scene Config**: 64 parallel environments
# 2. **Actions**: Joint velocity control with 20.0 scale
# 3. **Observations**: Normalized state variables
# 4. **Rewards**: Upright reward (5.0) + effort penalty (-0.01)
# 5. **Events**: Joint resets + random pushes
# 6. **Terminations**: Pole tipped (>30°) or timeout (10s)

# %%
# %%writefile ../src/mjlab/tasks/cartpole/env_cfg.py
"""CartPole task environment configuration."""

import math
import torch

from mjlab.envs import ManagerBasedRlEnvCfg
from mjlab.envs.mdp.actions import JointVelocityActionCfg
from mjlab.managers.observation_manager import ObservationGroupCfg, ObservationTermCfg
from mjlab.managers.reward_manager import RewardTermCfg
from mjlab.managers.termination_manager import TerminationTermCfg
from mjlab.managers.event_manager import EventTermCfg
from mjlab.managers.scene_entity_config import SceneEntityCfg
from mjlab.scene import SceneCfg
from mjlab.sim import MujocoCfg, SimulationCfg
from mjlab.viewer import ViewerConfig
from mjlab.asset_zoo.robots.cartpole.cartpole_constants import get_cartpole_robot_cfg
from mjlab.envs import mdp


def cartpole_env_cfg(play: bool = False) -> ManagerBasedRlEnvCfg:
  """Create CartPole environment configuration.

  Args:
    play: If True, disables corruption and extends episode length for evaluation.
  """

  # ==============================================================================
  # Scene Configuration
  # ==============================================================================

  scene_cfg = SceneCfg(
    num_envs=64 if not play else 16,  # Fewer envs for play mode
    extent=1.0,   # Spacing between environments
    entities={"robot": get_cartpole_robot_cfg()},
  )

  viewer_cfg = ViewerConfig(
    origin_type=ViewerConfig.OriginType.ASSET_BODY,
    entity_name="robot",
    body_name="pole",
    distance=3.0,
    elevation=10.0,
    azimuth=90.0,
  )

  sim_cfg = SimulationCfg(
    mujoco=MujocoCfg(
      timestep=0.02,  # 50 Hz control
      iterations=1,
    ),
  )

  # ==============================================================================
  # Actions
  # ==============================================================================

  actions = {
    "joint_pos": JointVelocityActionCfg(
      entity_name="robot",
      actuator_names=(".*",),
      scale=20.0,
      use_default_offset=False,
    ),
  }

  # ==============================================================================
  # Observations
  # ==============================================================================

  actor_terms = {
    "angle": ObservationTermCfg(
      func=lambda env: env.sim.data.qpos[:, 1:2] / math.pi
    ),
    "ang_vel": ObservationTermCfg(
      func=lambda env: env.sim.data.qvel[:, 1:2] / 5.0
    ),
    "cart_pos": ObservationTermCfg(
      func=lambda env: env.sim.data.qpos[:, 0:1] / 2.0
    ),
    "cart_vel": ObservationTermCfg(
      func=lambda env: env.sim.data.qvel[:, 0:1] / 20.0
    ),
  }

  observations = {
    "actor": ObservationGroupCfg(
      terms=actor_terms,
      concatenate_terms=True,
      enable_corruption=not play,  # Disable corruption in play mode
    ),
    "critic": ObservationGroupCfg(
      terms=actor_terms,  # Critic uses same observations
      concatenate_terms=True,
      enable_corruption=False,
    ),
  }

  # ==============================================================================
  # Rewards
  # ==============================================================================

  def compute_upright_reward(env):
    """Reward for keeping pole upright (cosine of angle)."""
    return env.sim.data.qpos[:, 1].cos()

  def compute_effort_penalty(env):
    """Penalty for control effort."""
    return -0.01 * (env.sim.data.ctrl[:, 0] ** 2)

  rewards = {
    "upright": RewardTermCfg(func=compute_upright_reward, weight=5.0),
    "effort": RewardTermCfg(func=compute_effort_penalty, weight=1.0),
  }

  # ==============================================================================
  # Events
  # ==============================================================================

  def random_push_cart(env, env_ids, force_range=(-5, 5)):
    """Apply random force to cart for robustness training."""
    n = len(env_ids)
    random_forces = (
      torch.rand(n, device=env.device) *
      (force_range[1] - force_range[0]) +
      force_range[0]
    )
    env.sim.data.qfrc_applied[env_ids, 0] = random_forces

  events = {
    "reset_robot_joints": EventTermCfg(
      func=mdp.reset_joints_by_offset,
      mode="reset",
      params={
        "asset_cfg": SceneEntityCfg("robot"),
        "position_range": (-0.1, 0.1),
        "velocity_range": (-0.1, 0.1),
      },
    ),
  }

  # Add random pushes only in training mode
  if not play:
    events["random_push"] = EventTermCfg(
      func=random_push_cart,
      mode="interval",
      interval_range_s=(1.0, 2.0),
      params={"force_range": (-20.0, 20.0)},
    )

  # ==============================================================================
  # Terminations
  # ==============================================================================

  def check_pole_tipped(env):
    """Check if pole has tipped beyond 30 degrees."""
    return env.sim.data.qpos[:, 1].abs() > math.radians(30)

  terminations = {
    "timeout": TerminationTermCfg(func=mdp.time_out, time_out=True),
    "tipped": TerminationTermCfg(func=check_pole_tipped, time_out=False),
  }

  # ==============================================================================
  # Environment Configuration
  # ==============================================================================

  return ManagerBasedRlEnvCfg(
    scene=scene_cfg,
    observations=observations,
    actions=actions,
    rewards=rewards,
    events=events,
    terminations=terminations,
    sim=sim_cfg,
    viewer=viewer_cfg,
    decimation=1,           # No action repeat
    episode_length_s=int(1e9) if play else 10.0,  # Infinite for play, 10s for training
  )
# Out:
# Overwriting ../src/mjlab/tasks/cartpole/env_cfg.py

# %% [markdown]
# ### **⚙️ Create RL Configuration**
#
# This file defines the PPO (Proximal Policy Optimization) training parameters.

# %%
# %%writefile ../src/mjlab/tasks/cartpole/rl_cfg.py
"""RL configuration for CartPole task."""

from mjlab.rl.config import (
  RslRlOnPolicyRunnerCfg,
  RslRlModelCfg,
  RslRlPpoAlgorithmCfg,
)


def cartpole_ppo_runner_cfg() -> RslRlOnPolicyRunnerCfg:
  """Create RL runner configuration for CartPole task."""
  return RslRlOnPolicyRunnerCfg(
    actor=RslRlModelCfg(
      hidden_dims=(256, 128, 64),  # Smaller network for simpler task
      activation="elu",
      obs_normalization=True,
      distribution_cfg={
        "class_name": "GaussianDistribution",
        "init_std": 1.0,
        "std_type": "scalar",
      },
    ),
    critic=RslRlModelCfg(
      hidden_dims=(256, 128, 64),
      activation="elu",
      obs_normalization=True,
    ),
    algorithm=RslRlPpoAlgorithmCfg(
      value_loss_coef=1.0,
      use_clipped_value_loss=True,
      clip_param=0.2,
      entropy_coef=0.01,
      num_learning_epochs=5,
      num_mini_batches=4,
      learning_rate=1.0e-3,
      schedule="adaptive",
      gamma=0.99,
      lam=0.95,
      desired_kl=0.01,
      max_grad_norm=1.0,
    ),
    experiment_name="cartpole",
    save_interval=50,
    num_steps_per_env=24,
    max_iterations=5_000,  # Fewer iterations for simpler task
  )
# Out:
# Overwriting ../src/mjlab/tasks/cartpole/rl_cfg.py

# %% [markdown]
# ### **📋 Register the Task Environment**
#
# Register the CartPole task with mjlab registry.

# %%
# %%writefile ../src/mjlab/tasks/cartpole/__init__.py
"""CartPole task registration."""

from mjlab.tasks.registry import register_mjlab_task
from mjlab.rl.runner import MjlabOnPolicyRunner

from .env_cfg import cartpole_env_cfg
from .rl_cfg import cartpole_ppo_runner_cfg

register_mjlab_task(
  task_id="Mjlab-Cartpole",
  env_cfg=cartpole_env_cfg(),
  play_env_cfg=cartpole_env_cfg(play=True),
  rl_cfg=cartpole_ppo_runner_cfg(),
  runner_cls=MjlabOnPolicyRunner,
)
# Out:
# Overwriting ../src/mjlab/tasks/cartpole/__init__.py

# %% [markdown]
# ---
#
# ## **🚀 Step 3: Train the Agent**
#
# Now let's train a PPO policy to balance the CartPole!

# %%
# !python -m mjlab.scripts.train Mjlab-Cartpole --agent.max-iterations 201 --agent.save-interval 20
# Out:
# [INFO] Training with: device=cuda:0, seed=42, rank=0
# [INFO] Logging experiment in directory: /home/marcocassar/workspace/projects/ml/mjlab/notebooks/logs/rsl_rl/cartpole/2026-07-25_14-23-59
# Setting seed: 42
# Warp 1.14.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.0
#    Devices:
#      "cpu"      : "aarch64"
#      "cuda:0"   : "NVIDIA GB10" (120 GiB, sm_121, mempool enabled)
#    Kernel cache:
#      /home/marcocassar/.cache/warp/1.14.0
# /home/marcocassar/workspace/projects/ml/mjlab/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(
# Module mujoco_warp._src.smooth e597d07 load on device 'cuda:0' took 2.90 ms  (cached)
# Module _nxn_broadphase__locals__kernel_df6640ed df6640e load on device 'cuda:0' took 0.37 ms  (cached)
# Module _primitive_narrowphase__locals__primitive_narrowphase_7b4e681e 7b4e681 load on device 'cuda:0' took 0.59 ms  (cached)
# Module mujoco_warp._src.constraint 880bd7f load on device 'cuda:0' took 0.27 ms  (cached)
# Module _friction_dof__locals__kernel_3c14efda 3c14efd load on device 'cuda:0' took 0.42 ms  (cached)
# Module _limit_slide_hinge__locals__kernel_4d6c55ab 4d6c55a load on device 'cuda:0' took 0.38 ms  (cached)
# Module _efc_contact_init__locals__kernel_07a590e0 07a590e load on device 'cuda:0' took 0.32 ms  (cached)
# Module _efc_contact_jac_dense__locals__kernel_5e1af9f9 1d73624 load on device 'cuda:0' took 0.37 ms  (cached)
# Module _efc_contact_update__locals__kernel_8aad7bfd 8aad7bf load on device 'cuda:0' took 0.32 ms  (cached)
# Module mujoco_warp._src.forward 687ddb7 load on device 'cuda:0' took 1.06 ms  (cached)
# Module mujoco_warp._src.passive 8ff6993 load on device 'cuda:0' took 1.14 ms  (cached)
# Module mujoco_warp._src.forward 2190340 load on device 'cuda:0' took 0.92 ms  (cached)
# Module _qfrc_smooth__locals__kernel_6eb3d958 6eb3d95 load on device 'cuda:0' took 0.26 ms  (cached)
# Module mujoco_warp._src.support d1e71d9 load on device 'cuda:0' took 0.28 ms  (cached)
# Module _small_cholesky_factorize_solve_block__locals__kernel_de44ded9 276e4ec load on device 'cuda:0' took 0.28 ms  (cached)
# Module _solve_init_dof__locals__kernel_99a497d1 99a497d load on device 'cuda:0' took 0.26 ms  (cached)
# Module mujoco_warp._src.solver 245b5b3 load on device 'cuda:0' took 1.68 ms  (cached)
# Module _solve_init_jaref_kernel__locals__kernel_f59a16d0 f59a16d load on device 'cuda:0' took 0.26 ms  (cached)
# Module mul_m_kernel__locals___mul_m_fd2186c4 fd2186c load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_constraint_efc__locals__kernel_4af8f110 4af8f11 load on device 'cuda:0' took 0.28 ms  (cached)
# Module _update_constraint_init_qfrc_constraint_dense__locals__kernel_391cb5b4 391cb5b load on device 'cuda:0' took 0.28 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_cb780630 cb78063 load on device 'cuda:0' took 0.27 ms  (cached)
# Module _update_gradient_grad__locals__kernel_0cbf4927 0cbf492 load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_gradient_JTDAJ_dense_tiled__locals__kernel_ddaa0f87 fe4fa40 load on device 'cuda:0' took 0.60 ms  (cached)
# Module _update_gradient_cholesky__locals__kernel_29c41a83 df60fb5 load on device 'cuda:0' took 27.05 ms  (cached)
# Module _linesearch_iterative_kernel__locals__kernel_fb5b8694 726f286 load on device 'cuda:0' took 0.57 ms  (cached)
# Module _update_constraint_efc__locals__kernel_e30beb1f e30beb1 load on device 'cuda:0' took 0.35 ms  (cached)
# Module _update_constraint_init_qfrc_constraint_dense__locals__kernel_5ba72bac 5ba72ba load on device 'cuda:0' took 0.30 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_f708ee5f f708ee5 load on device 'cuda:0' took 0.27 ms  (cached)
# Module _update_gradient_grad__locals__kernel_cb93df65 cb93df6 load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_gradient_cholesky__locals__kernel_219a556b f9b6ddc load on device 'cuda:0' took 26.43 ms  (cached)
# Module mujoco_warp._src.sensor 42e0a24 load on device 'cuda:0' took 1.60 ms  (cached)
# Module mujoco_warp._src.derivative e770e28 load on device 'cuda:0' took 0.71 ms  (cached)
# Module _next_time_builder__locals___next_time_95ad6d7a 95ad6d7 load on device 'cuda:0' took 0.33 ms  (cached)
# Module reset_data__locals__reset_xfrc_applied_03030511 0303051 load on device 'cuda:0' took 0.31 ms  (cached)
# Module reset_data__locals__reset_M_631075dd 631075d load on device 'cuda:0' took 0.25 ms  (cached)
# Module reset_data__locals__reset_mocap_6513201c 6513201 load on device 'cuda:0' took 0.24 ms  (cached)
# Module reset_data__locals__reset_contact_5c08f689 5c08f68 load on device 'cuda:0' took 0.25 ms  (cached)
# Module reset_data__locals__reset_sleep_50b990da 50b990d load on device 'cuda:0' took 0.25 ms  (cached)
# Module reset_data__locals__reset_nworld_69a10925 69a1092 load on device 'cuda:0' took 0.29 ms  (cached)
#
# +---------------------------------+
# |         Base Environment        |
# +------------------------+--------+
# | Property               | Value  |
# +------------------------+--------+
# | Number of environments | 64     |
# | Environment device     | cuda:0 |
# | Environment seed       | 42     |
# | Physics step-size      | 0.02   |
# | Environment step-size  | 0.02   |
# +------------------------+--------+
#
# [INFO] <EventManager> contains 2 active terms.
# +-------------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +--------+----------------------------+
# | Index  | Name                       |
# +--------+----------------------------+
# |   0    | reset_robot_joints         |
# +--------+----------------------------+
# +-----------------------------------------------+
# |     Active Event Terms in Mode: 'interval'    |
# +-------+-------------+-------------------------+
# | Index | Name        | Interval time range (s) |
# +-------+-------------+-------------------------+
# |   0   | random_push |        (1.0, 2.0)       |
# +-------+-------------+-------------------------+
#
# [INFO] <NullCommandManager> (inactive)
# [INFO] <ActionManager> contains 1 active terms.
# +--------------------------------+
# | Active Action Terms (shape: 1) |
# +-------+-----------+------------+
# | Index | Name      |  Dimension |
# +-------+-----------+------------+
# |   0   | joint_pos |          1 |
# +-------+-----------+------------+
#
# [INFO] <ObservationManager> contains 2 groups.
# +----------------------------------------------------------+
# | Active Observation Terms in Group: 'actor' (shape: (4,)) |
# +---------------+------------------------+-----------------+
# |     Index     | Name                   |      Shape      |
# +---------------+------------------------+-----------------+
# |       0       | angle                  |       (1,)      |
# |       1       | ang_vel                |       (1,)      |
# |       2       | cart_pos               |       (1,)      |
# |       3       | cart_vel               |       (1,)      |
# +---------------+------------------------+-----------------+
# +-----------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (4,)) |
# +----------------+------------------------+-----------------+
# |     Index      | Name                   |      Shape      |
# +----------------+------------------------+-----------------+
# |       0        | angle                  |       (1,)      |
# |       1        | ang_vel                |       (1,)      |
# |       2        | cart_pos               |       (1,)      |
# |       3        | cart_vel               |       (1,)      |
# +----------------+------------------------+-----------------+
#
# [INFO] <TerminationManager> contains 2 active terms.
# +----------------------------+
# |  Active Termination Terms  |
# +-------+---------+----------+
# | Index | Name    | Time Out |
# +-------+---------+----------+
# |   0   | timeout |   True   |
# |   1   | tipped  |  False   |
# +-------+---------+----------+
#
# [INFO] <RewardManager> contains 2 active terms.
# +--------------------------+
# |   Active Reward Terms    |
# +-------+---------+--------+
# | Index | Name    | Weight |
# +-------+---------+--------+
# |   0   | upright |    5.0 |
# |   1   | effort  |    1.0 |
# +-------+---------+--------+
#
# [INFO] <NullCurriculumManager> (inactive)
# [INFO] <NullMetricsManager> (inactive)
# [INFO] <NullRecorderManager> (inactive)
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 actor :  ('actor',)
# 	 critic :  ('critic',)
# --------------------------------------------------------------------------------
# Actor Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (distribution): GaussianDistribution()
#   (mlp): MLP(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# Critic Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (mlp): MLP(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# wandb: WARNING `start_method` is deprecated and will be removed in a future version of wandb. This setting is currently non-functional and safely ignored.
# wandb: Currently logged in as: marcocassar (marcocassar-belmont-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ setting up run cjg8cs11 (0.3s)
# wandb: Tracking run with wandb version 0.22.3
# wandb: Run data is saved locally in /home/marcocassar/workspace/projects/ml/mjlab/notebooks/wandb/run-20260725_142400-cjg8cs11
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2026-07-25_14-23-59
# wandb: ⭐️ View project at https://wandb.ai/marcocassar-belmont-university/mjlab
# wandb: 🚀 View run at https://wandb.ai/marcocassar-belmont-university/mjlab/runs/cjg8cs11
# Storing git diff for 'mjlab' in: /home/marcocassar/workspace/projects/ml/mjlab/notebooks/logs/rsl_rl/cartpole/2026-07-25_14-23-59/git/mjlab.diff
# ################################################################################
#                             Learning iteration 0/201
#
#                             Total steps: 1536
#                        Steps per second: 2331
#                         Collection time: 0.351s
#                           Learning time: 0.308s
#                         Mean value loss: 0.0797
#                     Mean surrogate loss: 0.0123
#                       Mean entropy loss: 1.4096
#                             Mean reward: 0.09
#                     Mean episode length: 8.69
#                         Mean action std: 0.98
#             Episode_Termination/timeout: 0.0909
#                  Episode_Reward/upright: 0.0751
#              Episode_Termination/tipped: 5.3182
#                   Episode_Reward/effort: -0.0677
# --------------------------------------------------------------------------------
#                          Iteration time: 0.66s
#                            Time elapsed: 0:00:00
#                                     ETA: 0:02:11
#
# ################################################################################
#                             Learning iteration 1/201
#
#                             Total steps: 3072
#                        Steps per second: 13675
#                         Collection time: 0.045s
#                           Learning time: 0.067s
#                         Mean value loss: 0.0565
#                     Mean surrogate loss: -0.0286
#                       Mean entropy loss: 1.3277
#                             Mean reward: 0.08
#                     Mean episode length: 9.32
#                         Mean action std: 0.88
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.0874
#              Episode_Termination/tipped: 7.4583
#                   Episode_Reward/effort: -0.0752
# --------------------------------------------------------------------------------
#                          Iteration time: 0.11s
#                            Time elapsed: 0:00:00
#                                     ETA: 0:01:16
#
# ################################################################################
#                             Learning iteration 2/201
#
#                             Total steps: 4608
#                        Steps per second: 14655
#                         Collection time: 0.046s
#                           Learning time: 0.059s
#                         Mean value loss: 0.0366
#                     Mean surrogate loss: -0.0347
#                       Mean entropy loss: 1.2277
#                             Mean reward: 0.29
#                     Mean episode length: 9.06
#                         Mean action std: 0.80
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.0869
#              Episode_Termination/tipped: 7.2500
#                   Episode_Reward/effort: -0.0588
# --------------------------------------------------------------------------------
#                          Iteration time: 0.10s
#                            Time elapsed: 0:00:00
#                                     ETA: 0:00:57
#
# ################################################################################
#                             Learning iteration 3/201
#
#                             Total steps: 6144
#                        Steps per second: 14521
#                         Collection time: 0.045s
#                           Learning time: 0.060s
#                         Mean value loss: 0.0523
#                     Mean surrogate loss: -0.0194
#                       Mean entropy loss: 1.1751
#                             Mean reward: 0.39
#                     Mean episode length: 9.59
#                         Mean action std: 0.77
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.0888
#              Episode_Termination/tipped: 5.9583
#                   Episode_Reward/effort: -0.0519
# --------------------------------------------------------------------------------
#                          Iteration time: 0.11s
#                            Time elapsed: 0:00:00
#                                     ETA: 0:00:48
#
# ################################################################################
#                             Learning iteration 4/201
#
#                             Total steps: 7680
#                        Steps per second: 16561
#                         Collection time: 0.043s
#                           Learning time: 0.050s
#                         Mean value loss: 0.0796
#                     Mean surrogate loss: -0.0292
#                       Mean entropy loss: 1.1161
#                             Mean reward: 0.65
#                     Mean episode length: 13.53
#                         Mean action std: 0.73
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.1366
#              Episode_Termination/tipped: 3.7826
#                   Episode_Reward/effort: -0.0644
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:42
#
# ################################################################################
#                             Learning iteration 5/201
#
#                             Total steps: 9216
#                        Steps per second: 16831
#                         Collection time: 0.043s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0868
#                     Mean surrogate loss: -0.0230
#                       Mean entropy loss: 1.0710
#                             Mean reward: 0.86
#                     Mean episode length: 17.61
#                         Mean action std: 0.69
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.1859
#              Episode_Termination/tipped: 2.4348
#                   Episode_Reward/effort: -0.0919
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:37
#
# ################################################################################
#                             Learning iteration 6/201
#
#                             Total steps: 10752
#                        Steps per second: 17719
#                         Collection time: 0.039s
#                           Learning time: 0.047s
#                         Mean value loss: 0.0956
#                     Mean surrogate loss: -0.0086
#                       Mean entropy loss: 1.0188
#                             Mean reward: 1.14
#                     Mean episode length: 23.88
#                         Mean action std: 0.65
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.3728
#              Episode_Termination/tipped: 1.6000
#                   Episode_Reward/effort: -0.1930
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:34
#
# ################################################################################
#                             Learning iteration 7/201
#
#                             Total steps: 12288
#                        Steps per second: 16909
#                         Collection time: 0.041s
#                           Learning time: 0.050s
#                         Mean value loss: 0.1176
#                     Mean surrogate loss: -0.0141
#                       Mean entropy loss: 0.9577
#                             Mean reward: 1.59
#                     Mean episode length: 31.72
#                         Mean action std: 0.61
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.4143
#              Episode_Termination/tipped: 1.9444
#                   Episode_Reward/effort: -0.1904
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:32
#
# ################################################################################
#                             Learning iteration 8/201
#
#                             Total steps: 13824
#                        Steps per second: 10785
#                         Collection time: 0.040s
#                           Learning time: 0.103s
#                         Mean value loss: 0.1368
#                     Mean surrogate loss: -0.0142
#                       Mean entropy loss: 0.8752
#                             Mean reward: 1.92
#                     Mean episode length: 37.68
#                         Mean action std: 0.55
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.5000
#              Episode_Termination/tipped: 1.3333
#                   Episode_Reward/effort: -0.2287
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:31
#
# ################################################################################
#                             Learning iteration 9/201
#
#                             Total steps: 15360
#                        Steps per second: 10572
#                         Collection time: 0.038s
#                           Learning time: 0.108s
#                         Mean value loss: 0.1538
#                     Mean surrogate loss: -0.0127
#                       Mean entropy loss: 0.7465
#                             Mean reward: 2.18
#                     Mean episode length: 41.78
#                         Mean action std: 0.49
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.5194
#              Episode_Termination/tipped: 1.2000
#                   Episode_Reward/effort: -0.2139
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:31
#
# ################################################################################
#                            Learning iteration 10/201
#
#                             Total steps: 16896
#                        Steps per second: 9810
#                         Collection time: 0.037s
#                           Learning time: 0.120s
#                         Mean value loss: 0.1565
#                     Mean surrogate loss: -0.0063
#                       Mean entropy loss: 0.6723
#                             Mean reward: 2.49
#                     Mean episode length: 46.47
#                         Mean action std: 0.46
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 0.8135
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.3053
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:30
#
# ################################################################################
#                            Learning iteration 11/201
#
#                             Total steps: 18432
#                        Steps per second: 10352
#                         Collection time: 0.036s
#                           Learning time: 0.112s
#                         Mean value loss: 0.1582
#                     Mean surrogate loss: -0.0003
#                       Mean entropy loss: 0.6016
#                             Mean reward: 2.91
#                     Mean episode length: 52.85
#                         Mean action std: 0.44
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.1396
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4215
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:01
#                                     ETA: 0:00:30
#
# ################################################################################
#                            Learning iteration 12/201
#
#                             Total steps: 19968
#                        Steps per second: 9812
#                         Collection time: 0.036s
#                           Learning time: 0.121s
#                         Mean value loss: 0.1374
#                     Mean surrogate loss: -0.0065
#                       Mean entropy loss: 0.5504
#                             Mean reward: 3.42
#                     Mean episode length: 59.87
#                         Mean action std: 0.40
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.1802
#              Episode_Termination/tipped: 1.1667
#                   Episode_Reward/effort: -0.3832
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:30
#
# ################################################################################
#                            Learning iteration 13/201
#
#                             Total steps: 21504
#                        Steps per second: 9716
#                         Collection time: 0.035s
#                           Learning time: 0.123s
#                         Mean value loss: 0.1457
#                     Mean surrogate loss: -0.0035
#                       Mean entropy loss: 0.4451
#                             Mean reward: 3.81
#                     Mean episode length: 65.07
#                         Mean action std: 0.37
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.4296
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4493
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:30
#
# ################################################################################
#                            Learning iteration 14/201
#
#                             Total steps: 23040
#                        Steps per second: 10335
#                         Collection time: 0.035s
#                           Learning time: 0.114s
#                         Mean value loss: 0.1486
#                     Mean surrogate loss: -0.0081
#                       Mean entropy loss: 0.3719
#                             Mean reward: 4.19
#                     Mean episode length: 69.86
#                         Mean action std: 0.34
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.6010
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4669
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:29
#
# ################################################################################
#                            Learning iteration 15/201
#
#                             Total steps: 24576
#                        Steps per second: 10604
#                         Collection time: 0.034s
#                           Learning time: 0.111s
#                         Mean value loss: 0.1745
#                     Mean surrogate loss: -0.0017
#                       Mean entropy loss: 0.2970
#                             Mean reward: 4.40
#                     Mean episode length: 72.46
#                         Mean action std: 0.32
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.8409
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4824
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:29
#
# ################################################################################
#                            Learning iteration 16/201
#
#                             Total steps: 26112
#                        Steps per second: 10065
#                         Collection time: 0.034s
#                           Learning time: 0.118s
#                         Mean value loss: 0.1337
#                     Mean surrogate loss: -0.0033
#                       Mean entropy loss: 0.2063
#                             Mean reward: 4.73
#                     Mean episode length: 76.62
#                         Mean action std: 0.28
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 1.8056
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4475
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:29
#
# ################################################################################
#                            Learning iteration 17/201
#
#                             Total steps: 27648
#                        Steps per second: 10210
#                         Collection time: 0.033s
#                           Learning time: 0.117s
#                         Mean value loss: 0.1443
#                     Mean surrogate loss: -0.0040
#                       Mean entropy loss: 0.1117
#                             Mean reward: 5.07
#                     Mean episode length: 80.89
#                         Mean action std: 0.26
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 2.4588
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.5795
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:28
#
# ################################################################################
#                            Learning iteration 18/201
#
#                             Total steps: 29184
#                        Steps per second: 10601
#                         Collection time: 0.033s
#                           Learning time: 0.112s
#                         Mean value loss: 0.1525
#                     Mean surrogate loss: 0.0096
#                       Mean entropy loss: 0.0623
#                             Mean reward: 5.07
#                     Mean episode length: 80.89
#                         Mean action std: 0.25
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:02
#                                     ETA: 0:00:28
#
# ################################################################################
#                            Learning iteration 19/201
#
#                             Total steps: 30720
#                        Steps per second: 10251
#                         Collection time: 0.035s
#                           Learning time: 0.115s
#                         Mean value loss: 0.1274
#                     Mean surrogate loss: 0.0079
#                       Mean entropy loss: 0.0673
#                             Mean reward: 5.91
#                     Mean episode length: 90.40
#                         Mean action std: 0.26
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 2.2777
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4050
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:28
#
# ################################################################################
#                            Learning iteration 20/201
#
#                             Total steps: 32256
#                        Steps per second: 10581
#                         Collection time: 0.034s
#                           Learning time: 0.111s
#                         Mean value loss: 0.1318
#                     Mean surrogate loss: 0.0073
#                       Mean entropy loss: 0.0290
#                             Mean reward: 6.37
#                     Mean episode length: 96.25
#                         Mean action std: 0.25
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 3.1777
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.6808
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:28
#
# ################################################################################
#                            Learning iteration 21/201
#
#                             Total steps: 33792
#                        Steps per second: 10123
#                         Collection time: 0.034s
#                           Learning time: 0.118s
#                         Mean value loss: 0.1126
#                     Mean surrogate loss: 0.0013
#                       Mean entropy loss: -0.0159
#                             Mean reward: 6.83
#                     Mean episode length: 101.61
#                         Mean action std: 0.23
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 2.9548
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.5297
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:27
#
# ################################################################################
#                            Learning iteration 22/201
#
#                             Total steps: 35328
#                        Steps per second: 10896
#                         Collection time: 0.033s
#                           Learning time: 0.108s
#                         Mean value loss: 0.0880
#                     Mean surrogate loss: 0.0018
#                       Mean entropy loss: -0.0760
#                             Mean reward: 7.03
#                     Mean episode length: 103.62
#                         Mean action std: 0.22
#             Episode_Termination/timeout: 0.0000
#                  Episode_Reward/upright: 2.7473
#              Episode_Termination/tipped: 1.0000
#                   Episode_Reward/effort: -0.4162
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:27
#
# ################################################################################
#                            Learning iteration 23/201
#
#                             Total steps: 36864
#                        Steps per second: 10771
#                         Collection time: 0.032s
#                           Learning time: 0.110s
#                         Mean value loss: 0.0690
#                     Mean surrogate loss: 0.0023
#                       Mean entropy loss: -0.1108
#                             Mean reward: 7.03
#                     Mean episode length: 103.62
#                         Mean action std: 0.21
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:27
#
# ################################################################################
#                            Learning iteration 24/201
#
#                             Total steps: 38400
#                        Steps per second: 10249
#                         Collection time: 0.032s
#                           Learning time: 0.118s
#                         Mean value loss: 0.0488
#                     Mean surrogate loss: 0.0023
#                       Mean entropy loss: -0.1729
#                             Mean reward: 7.03
#                     Mean episode length: 103.62
#                         Mean action std: 0.20
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:03
#                                     ETA: 0:00:27
#
# ################################################################################
#                            Learning iteration 25/201
#
#                             Total steps: 39936
#                        Steps per second: 10079
#                         Collection time: 0.032s
#                           Learning time: 0.120s
#                         Mean value loss: 0.0510
#                     Mean surrogate loss: -0.0012
#                       Mean entropy loss: -0.2365
#                             Mean reward: 7.03
#                     Mean episode length: 103.62
#                         Mean action std: 0.18
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:27
#
# ################################################################################
#                            Learning iteration 26/201
#
#                             Total steps: 41472
#                        Steps per second: 9790
#                         Collection time: 0.033s
#                           Learning time: 0.124s
#                         Mean value loss: 0.0526
#                     Mean surrogate loss: 0.0043
#                       Mean entropy loss: -0.3140
#                             Mean reward: 7.79
#                     Mean episode length: 113.10
#                         Mean action std: 0.18
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9551
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.9658
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 27/201
#
#                             Total steps: 43008
#                        Steps per second: 10189
#                         Collection time: 0.032s
#                           Learning time: 0.118s
#                         Mean value loss: 0.0588
#                     Mean surrogate loss: 0.0058
#                       Mean entropy loss: -0.3264
#                             Mean reward: 8.18
#                     Mean episode length: 117.66
#                         Mean action std: 0.18
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9516
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.8214
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 28/201
#
#                             Total steps: 44544
#                        Steps per second: 10632
#                         Collection time: 0.041s
#                           Learning time: 0.104s
#                         Mean value loss: 0.0836
#                     Mean surrogate loss: 0.0075
#                       Mean entropy loss: -0.3292
#                             Mean reward: 11.02
#                     Mean episode length: 149.92
#                         Mean action std: 0.17
#             Episode_Termination/timeout: 1.1667
#                  Episode_Reward/upright: 4.9577
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.7001
# --------------------------------------------------------------------------------
#                          Iteration time: 0.14s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 29/201
#
#                             Total steps: 46080
#                        Steps per second: 9975
#                         Collection time: 0.035s
#                           Learning time: 0.119s
#                         Mean value loss: 0.0259
#                     Mean surrogate loss: -0.0034
#                       Mean entropy loss: -0.4175
#                             Mean reward: 13.47
#                     Mean episode length: 176.94
#                         Mean action std: 0.16
#             Episode_Termination/timeout: 1.2000
#                  Episode_Reward/upright: 4.9737
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.6031
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 30/201
#
#                             Total steps: 47616
#                        Steps per second: 10352
#                         Collection time: 0.034s
#                           Learning time: 0.114s
#                         Mean value loss: 0.0257
#                     Mean surrogate loss: 0.0019
#                       Mean entropy loss: -0.4175
#                             Mean reward: 15.55
#                     Mean episode length: 199.12
#                         Mean action std: 0.16
#             Episode_Termination/timeout: 1.6667
#                  Episode_Reward/upright: 4.9685
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.4998
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 31/201
#
#                             Total steps: 49152
#                        Steps per second: 9858
#                         Collection time: 0.034s
#                           Learning time: 0.122s
#                         Mean value loss: 0.0718
#                     Mean surrogate loss: 0.0045
#                       Mean entropy loss: -0.4251
#                             Mean reward: 17.29
#                     Mean episode length: 218.18
#                         Mean action std: 0.16
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9759
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.5035
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:04
#                                     ETA: 0:00:26
#
# ################################################################################
#                            Learning iteration 32/201
#
#                             Total steps: 50688
#                        Steps per second: 9944
#                         Collection time: 0.036s
#                           Learning time: 0.118s
#                         Mean value loss: 0.0164
#                     Mean surrogate loss: 0.0009
#                       Mean entropy loss: -0.4685
#                             Mean reward: 21.59
#                     Mean episode length: 263.66
#                         Mean action std: 0.15
#             Episode_Termination/timeout: 1.1111
#                  Episode_Reward/upright: 4.9716
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.4341
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:05
#                                     ETA: 0:00:25
#
# ################################################################################
#                            Learning iteration 33/201
#
#                             Total steps: 52224
#                        Steps per second: 10445
#                         Collection time: 0.034s
#                           Learning time: 0.113s
#                         Mean value loss: 0.0324
#                     Mean surrogate loss: 0.0055
#                       Mean entropy loss: -0.5038
#                             Mean reward: 23.23
#                     Mean episode length: 280.20
#                         Mean action std: 0.15
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9788
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.3960
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:05
#                                     ETA: 0:00:25
#
# ################################################################################
#                            Learning iteration 34/201
#
#                             Total steps: 53760
#                        Steps per second: 10152
#                         Collection time: 0.035s
#                           Learning time: 0.116s
#                         Mean value loss: 0.0492
#                     Mean surrogate loss: 0.0032
#                       Mean entropy loss: -0.5363
#                             Mean reward: 25.84
#                     Mean episode length: 306.83
#                         Mean action std: 0.14
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9849
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.3447
# --------------------------------------------------------------------------------
#                          Iteration time: 0.15s
#                            Time elapsed: 0:00:05
#                                     ETA: 0:00:25
#
# ################################################################################
#                            Learning iteration 35/201
#
#                             Total steps: 55296
#                        Steps per second: 9840
#                         Collection time: 0.050s
#                           Learning time: 0.106s
#                         Mean value loss: 0.0129
#                     Mean surrogate loss: 0.0065
#                       Mean entropy loss: -0.5442
#                             Mean reward: 26.72
#                     Mean episode length: 315.80
#                         Mean action std: 0.14
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9755
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.2878
# --------------------------------------------------------------------------------
#                          Iteration time: 0.16s
#                            Time elapsed: 0:00:05
#                                     ETA: 0:00:25
#
# ...
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0016
#                       Mean entropy loss: -4.0944
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9998
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0036
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 189/201
#
#                             Total steps: 291840
#                        Steps per second: 19210
#                         Collection time: 0.032s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0049
#                       Mean entropy loss: -4.1575
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 190/201
#
#                             Total steps: 293376
#                        Steps per second: 19301
#                         Collection time: 0.032s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0145
#                       Mean entropy loss: -4.1140
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 191/201
#
#                             Total steps: 294912
#                        Steps per second: 19411
#                         Collection time: 0.032s
#                           Learning time: 0.047s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0061
#                       Mean entropy loss: -4.1794
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 192/201
#
#                             Total steps: 296448
#                        Steps per second: 19181
#                         Collection time: 0.033s
#                           Learning time: 0.047s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0112
#                       Mean entropy loss: -4.1163
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9995
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0046
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 193/201
#
#                             Total steps: 297984
#                        Steps per second: 18859
#                         Collection time: 0.033s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0046
#                       Mean entropy loss: -4.1368
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9992
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0059
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:01
#
# ################################################################################
#                            Learning iteration 194/201
#
#                             Total steps: 299520
#                        Steps per second: 19738
#                         Collection time: 0.033s
#                           Learning time: 0.045s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0022
#                       Mean entropy loss: -4.1381
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9994
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0049
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:27
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 195/201
#
#                             Total steps: 301056
#                        Steps per second: 17749
#                         Collection time: 0.035s
#                           Learning time: 0.052s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: -0.0004
#                       Mean entropy loss: -4.2105
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.2000
#                  Episode_Reward/upright: 4.9996
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0038
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 196/201
#
#                             Total steps: 302592
#                        Steps per second: 18725
#                         Collection time: 0.034s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0003
#                       Mean entropy loss: -4.1358
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.2500
#                  Episode_Reward/upright: 4.9995
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0050
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 197/201
#
#                             Total steps: 304128
#                        Steps per second: 19105
#                         Collection time: 0.034s
#                           Learning time: 0.046s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0068
#                       Mean entropy loss: -4.0944
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.5000
#                  Episode_Reward/upright: 4.9995
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0049
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 198/201
#
#                             Total steps: 305664
#                        Steps per second: 18612
#                         Collection time: 0.035s
#                           Learning time: 0.048s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0039
#                       Mean entropy loss: -4.0952
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9995
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0037
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 199/201
#
#                             Total steps: 307200
#                        Steps per second: 17994
#                         Collection time: 0.036s
#                           Learning time: 0.049s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: 0.0038
#                       Mean entropy loss: -3.9788
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.1111
#                  Episode_Reward/upright: 4.9995
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0039
# --------------------------------------------------------------------------------
#                          Iteration time: 0.09s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# ################################################################################
#                            Learning iteration 200/201
#
#                             Total steps: 308736
#                        Steps per second: 18988
#                         Collection time: 0.034s
#                           Learning time: 0.047s
#                         Mean value loss: 0.0000
#                     Mean surrogate loss: -0.0016
#                       Mean entropy loss: -3.9510
#                             Mean reward: 49.95
#                     Mean episode length: 500.00
#                         Mean action std: 0.00
#             Episode_Termination/timeout: 1.0000
#                  Episode_Reward/upright: 4.9994
#              Episode_Termination/tipped: 0.0000
#                   Episode_Reward/effort: -0.0052
# --------------------------------------------------------------------------------
#                          Iteration time: 0.08s
#                            Time elapsed: 0:00:28
#                                     ETA: 0:00:00
#
# wandb: ⢿ Finishing up...
# wandb: ⣻ Finishing up...
# wandb: ⣽ Finishing up...
# wandb: ⣾ Finishing up...
# wandb: ⣷ uploading history steps 95-198, console lines 2064-4283 (0.4s)
# wandb: ⣷ uploading model_200.pt 1019.0KB/1019.0KB (0.2s)
# wandb: ⣷ uploading config.yaml 16.2KB/16.2KB (0.0s)
# wandb: ⣯ uploading history steps 95-198, console lines 2064-4283 (0.4s)
# wandb: ⣯ uploading model_200.pt 1019.0KB/1019.0KB (0.2s)
# wandb: ⣯ uploading config.yaml 16.2KB/16.2KB (0.0s)
# wandb: ⣟ uploading history steps 95-198, console lines 2064-4283 (0.4s)
# wandb: ⣟ uploading model_200.pt 1019.0KB/1019.0KB (0.2s)
# wandb: ⣟ uploading config.yaml 16.2KB/16.2KB (0.0s)
# wandb: ⡿ uploading history steps 95-198, console lines 2064-4283 (0.4s)
# wandb: ⡿ uploading model_200.pt 1019.0KB/1019.0KB (0.2s)
# wandb: ⡿ uploading config.yaml 16.2KB/16.2KB (0.0s)
# wandb: ⢿ uploading history steps 95-198, console lines 2064-4283 (0.4s)
# wandb: ⢿ uploading model_200.pt 1019.0KB/1019.0KB (0.2s)
# wandb: ⢿ uploading config.yaml 16.2KB/16.2KB (0.0s)
# wandb: ⣻ uploading history steps 199-200, summary, console lines 4284-4305 (0...
# wandb: ⣽ uploading history steps 199-200, summary, console lines 4284-4305 (0...
# wandb: ⣾ uploading history steps 199-200, summary, console lines 4284-4305 (0...
# wandb: ⣷ uploading history steps 199-200, summary, console lines 4284-4305 (0...
# wandb: ⣯ uploading history steps 199-200, summary, console lines 4284-4305 (0...
# wandb:
# wandb: Run history:
# wandb:       Episode_Reward/effort ▇▅▅▃▂▁▂▃▃▅▆▆▆▇██████████████████████████
# wandb:      Episode_Reward/upright ▁▁▂▃▃███████████████████████████████████
# wandb: Episode_Termination/timeout ▁▁▁▁▆▇▆▆▇▇▆▆▆▆▆▆▆▇▇█▆▆▆▆▆▆▆▆▆▆▆█▆▆▆▆▆▆▇▆
# wandb:  Episode_Termination/tipped █▆▆▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                Loss/entropy ██▇▆▆▅▅▅▅▅▄▄▄▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁
# wandb:          Loss/learning_rate ▃▃█▄▁▃▂▃█▄▃▂▆▂▁▂▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁
# wandb:              Loss/surrogate ▆▅▄▂▄▁▃▅▂▅▄▂▃▅▄▅▄▃▁▃▂▃▂▂▅▇▃▆▅▇▅▄▃▅▄▃▅▅█▃
# wandb:                  Loss/value ▅█▇█▇▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:        Perf/collection_time ▃▂▁▁▁█▁▁▂▂▂▂▁▁▁▂▂▁▁▁▁▂▂▆▂▁▁▂▁▁▂▂▂▁▁▂▂▂▁▁
# wandb:          Perf/learning_time ▃▂▇█▇▆▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇▇▆▇█▇▇▇▇▇▇▇▇▆▇▁▁▁▁
# wandb:                          +4 ...
# wandb:
# wandb: Run summary:
# wandb:       Episode_Reward/effort -0.00525
# wandb:      Episode_Reward/upright 4.99945
# wandb: Episode_Termination/timeout 1
# wandb:  Episode_Termination/tipped 0
# wandb:                Loss/entropy -3.95103
# wandb:          Loss/learning_rate 0.00038
# wandb:              Loss/surrogate -0.00157
# wandb:                  Loss/value 1e-05
# wandb:        Perf/collection_time 0.03419
# wandb:          Perf/learning_time 0.0467
# wandb:                          +4 ...
# wandb:
# wandb: 🚀 View run 2026-07-25_14-23-59 at: https://wandb.ai/marcocassar-belmont-university/mjlab/runs/cjg8cs11
# wandb: ⭐️ View project at: https://wandb.ai/marcocassar-belmont-university/mjlab
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 12 other file(s)
# wandb: Find logs at: ./wandb/run-20260725_142400-cjg8cs11/logs

# %% [markdown]
# ### **📁 Locate Training Checkpoints**
#
# After training, checkpoints are saved locally.

# %%
import os
import re
from pathlib import Path

# Find the most recent training run
log_dir = Path("../logs/rsl_rl/cartpole")
if log_dir.exists():
  runs = sorted(log_dir.glob("*"), key=os.path.getmtime, reverse=True)
  if runs:
    latest_run = runs[0]
    print(f"✓ Latest training run: {latest_run.name}\n")

    # List checkpoints - sorted by iteration number
    checkpoints = list(latest_run.glob("model_*.pt"))
    if checkpoints:
      # Extract iteration number and sort numerically
      def get_iteration(ckpt):
        match = re.search(r"model_(\d+)\.pt", ckpt.name)
        return int(match.group(1)) if match else 0

      checkpoints = sorted(checkpoints, key=get_iteration)

      print(f"Found {len(checkpoints)} checkpoints:")
      for ckpt in checkpoints[-5:]:  # Show last 5
        size_mb = ckpt.stat().st_size / (1024 * 1024)
        iteration = get_iteration(ckpt)
        print(f"  • {ckpt.name} (iteration {iteration}, {size_mb:.2f} MB)")

      # Store the last checkpoint path
      last_checkpoint = str(checkpoints[-1])
      print(f"\n💾 Last checkpoint: {last_checkpoint}")
    else:
      print("⚠ No checkpoints found yet")
  else:
    print("⚠ No training runs found")
else:
  print("⚠ Log directory not found. Have you run training yet?")
# Out:
# ✓ Latest training run: 2026-07-25_14-23-09
#
# Found 2 checkpoints:
#   • model_0.pt (iteration 0, 0.99 MB)
#   • model_2.pt (iteration 2, 0.99 MB)
#
# 💾 Last checkpoint: ../logs/rsl_rl/cartpole/2026-07-25_14-23-09/model_2.pt

# %% [markdown]
# ---
#
# ## **🎮 Step 4: Visualize the Trained Policy**
#
# Let's see the trained policy in action!

# %% [markdown]
# ### **🌐 Launch Viser API**

# %%
import subprocess
import sys

process = subprocess.Popen(
  [
    "python",
    "-m",
    "mjlab.scripts.play",
    "Mjlab-Cartpole",
    "--checkpoint_file",
    last_checkpoint,
    "--num_envs",
    "4",
  ],
  stdout=subprocess.PIPE,
  stderr=subprocess.STDOUT,
  universal_newlines=True,
  bufsize=1,
)

detected_port = None

for line in process.stdout:
  print(line, end="")
  sys.stdout.flush()

  # Extract port number from viser output
  port_match = re.search(r":(\d{4})", line)
  if port_match and "viser" in line.lower():
    detected_port = int(port_match.group(1))
    print("\n" + "=" * 34)
    print(f"✅ Server is running on port {detected_port}!")
    print("=" * 34)
    break
# Out:
# [INFO]: Loading checkpoint: model_2.pt
# /home/marcocassar/workspace/projects/ml/mjlab/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GB10 which is of cuda capability 12.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (8.0) - (12.0)
#
#   warnings.warn(
# Warp 1.14.0 initialized:
#    CUDA Toolkit 12.9, Driver 13.0
#    Devices:
#      "cpu"      : "aarch64"
#      "cuda:0"   : "NVIDIA GB10" (120 GiB, sm_121, mempool enabled)
#    Kernel cache:
#      /home/marcocassar/.cache/warp/1.14.0
# Module mujoco_warp._src.smooth e597d07 load on device 'cuda:0' took 2.74 ms  (cached)
# Module _nxn_broadphase__locals__kernel_df6640ed df6640e load on device 'cuda:0' took 0.30 ms  (cached)
# Module _primitive_narrowphase__locals__primitive_narrowphase_7b4e681e 7b4e681 load on device 'cuda:0' took 0.49 ms  (cached)
# Module mujoco_warp._src.constraint 880bd7f load on device 'cuda:0' took 0.24 ms  (cached)
# Module _friction_dof__locals__kernel_3c14efda 3c14efd load on device 'cuda:0' took 0.31 ms  (cached)
# Module _limit_slide_hinge__locals__kernel_4d6c55ab 4d6c55a load on device 'cuda:0' took 0.30 ms  (cached)
# Module _efc_contact_init__locals__kernel_07a590e0 07a590e load on device 'cuda:0' took 0.28 ms  (cached)
# Module _efc_contact_jac_dense__locals__kernel_5e1af9f9 1d73624 load on device 'cuda:0' took 0.34 ms  (cached)
# Module _efc_contact_update__locals__kernel_8aad7bfd 8aad7bf load on device 'cuda:0' took 0.29 ms  (cached)
# Module mujoco_warp._src.forward 687ddb7 load on device 'cuda:0' took 1.05 ms  (cached)
# Module mujoco_warp._src.passive 8ff6993 load on device 'cuda:0' took 1.09 ms  (cached)
# Module mujoco_warp._src.forward 2190340 load on device 'cuda:0' took 0.85 ms  (cached)
# Module _qfrc_smooth__locals__kernel_6eb3d958 6eb3d95 load on device 'cuda:0' took 0.24 ms  (cached)
# Module mujoco_warp._src.support d1e71d9 load on device 'cuda:0' took 0.27 ms  (cached)
# Module _small_cholesky_factorize_solve_block__locals__kernel_de44ded9 276e4ec load on device 'cuda:0' took 0.26 ms  (cached)
# Module _solve_init_dof__locals__kernel_99a497d1 99a497d load on device 'cuda:0' took 0.25 ms  (cached)
# Module mujoco_warp._src.solver 245b5b3 load on device 'cuda:0' took 1.51 ms  (cached)
# Module _solve_init_jaref_kernel__locals__kernel_f59a16d0 f59a16d load on device 'cuda:0' took 0.25 ms  (cached)
# Module mul_m_kernel__locals___mul_m_fd2186c4 fd2186c load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_constraint_efc__locals__kernel_4af8f110 4af8f11 load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_constraint_init_qfrc_constraint_dense__locals__kernel_391cb5b4 391cb5b load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_cb780630 cb78063 load on device 'cuda:0' took 0.25 ms  (cached)
# Module _update_gradient_grad__locals__kernel_0cbf4927 0cbf492 load on device 'cuda:0' took 0.25 ms  (cached)
# Module _update_gradient_JTDAJ_dense_tiled__locals__kernel_ddaa0f87 fe4fa40 load on device 'cuda:0' took 0.59 ms  (cached)
# Module _update_gradient_cholesky__locals__kernel_29c41a83 df60fb5 load on device 'cuda:0' took 26.94 ms  (cached)
# Module _linesearch_iterative_kernel__locals__kernel_fb5b8694 726f286 load on device 'cuda:0' took 0.49 ms  (cached)
# Module _update_constraint_efc__locals__kernel_e30beb1f e30beb1 load on device 'cuda:0' took 0.31 ms  (cached)
# Module _update_constraint_init_qfrc_constraint_dense__locals__kernel_5ba72bac 5ba72ba load on device 'cuda:0' took 0.29 ms  (cached)
# Module _update_gradient_zero_grad_dot__locals__kernel_f708ee5f f708ee5 load on device 'cuda:0' took 0.26 ms  (cached)
# Module _update_gradient_grad__locals__kernel_cb93df65 cb93df6 load on device 'cuda:0' took 0.25 ms  (cached)
# Module _update_gradient_cholesky__locals__kernel_219a556b f9b6ddc load on device 'cuda:0' took 26.10 ms  (cached)
# Module mujoco_warp._src.sensor 42e0a24 load on device 'cuda:0' took 1.52 ms  (cached)
# Module mujoco_warp._src.derivative e770e28 load on device 'cuda:0' took 0.67 ms  (cached)
# Module _next_time_builder__locals___next_time_95ad6d7a 95ad6d7 load on device 'cuda:0' took 0.30 ms  (cached)
# Module reset_data__locals__reset_xfrc_applied_03030511 0303051 load on device 'cuda:0' took 0.29 ms  (cached)
# Module reset_data__locals__reset_M_631075dd 631075d load on device 'cuda:0' took 0.23 ms  (cached)
# Module reset_data__locals__reset_mocap_6513201c 6513201 load on device 'cuda:0' took 0.23 ms  (cached)
# Module reset_data__locals__reset_contact_5c08f689 5c08f68 load on device 'cuda:0' took 0.24 ms  (cached)
# Module reset_data__locals__reset_sleep_50b990da 50b990d load on device 'cuda:0' took 0.23 ms  (cached)
# Module reset_data__locals__reset_nworld_69a10925 69a1092 load on device 'cuda:0' took 0.28 ms  (cached)
#
# +---------------------------------+
# |         Base Environment        |
# +------------------------+--------+
# | Property               | Value  |
# +------------------------+--------+
# | Number of environments | 4      |
# | Environment device     | cuda:0 |
# | Environment seed       | None   |
# | Physics step-size      | 0.02   |
# | Environment step-size  | 0.02   |
# +------------------------+--------+
#
# [INFO] <EventManager> contains 1 active terms.
# +-------------------------------------+
# | Active Event Terms in Mode: 'reset' |
# +--------+----------------------------+
# | Index  | Name                       |
# +--------+----------------------------+
# |   0    | reset_robot_joints         |
# +--------+----------------------------+
#
# [INFO] <NullCommandManager> (inactive)
# [INFO] <ActionManager> contains 1 active terms.
# +--------------------------------+
# | Active Action Terms (shape: 1) |
# +-------+-----------+------------+
# | Index | Name      |  Dimension |
# +-------+-----------+------------+
# |   0   | joint_pos |          1 |
# +-------+-----------+------------+
#
# [INFO] <ObservationManager> contains 2 groups.
# +----------------------------------------------------------+
# | Active Observation Terms in Group: 'actor' (shape: (4,)) |
# +---------------+------------------------+-----------------+
# |     Index     | Name                   |      Shape      |
# +---------------+------------------------+-----------------+
# |       0       | angle                  |       (1,)      |
# |       1       | ang_vel                |       (1,)      |
# |       2       | cart_pos               |       (1,)      |
# |       3       | cart_vel               |       (1,)      |
# +---------------+------------------------+-----------------+
# +-----------------------------------------------------------+
# | Active Observation Terms in Group: 'critic' (shape: (4,)) |
# +----------------+------------------------+-----------------+
# |     Index      | Name                   |      Shape      |
# +----------------+------------------------+-----------------+
# |       0        | angle                  |       (1,)      |
# |       1        | ang_vel                |       (1,)      |
# |       2        | cart_pos               |       (1,)      |
# |       3        | cart_vel               |       (1,)      |
# +----------------+------------------------+-----------------+
#
# [INFO] <TerminationManager> contains 2 active terms.
# +----------------------------+
# |  Active Termination Terms  |
# +-------+---------+----------+
# | Index | Name    | Time Out |
# +-------+---------+----------+
# |   0   | timeout |   True   |
# |   1   | tipped  |  False   |
# +-------+---------+----------+
#
# [INFO] <RewardManager> contains 2 active terms.
# +--------------------------+
# |   Active Reward Terms    |
# +-------+---------+--------+
# | Index | Name    | Weight |
# +-------+---------+--------+
# |   0   | upright |    5.0 |
# |   1   | effort  |    1.0 |
# +-------+---------+--------+
#
# [INFO] <NullCurriculumManager> (inactive)
# [INFO] <NullMetricsManager> (inactive)
# [INFO] <NullRecorderManager> (inactive)
# --------------------------------------------------------------------------------
# Resolved observation sets:
# 	 actor :  ('actor',)
# 	 critic :  ('critic',)
# --------------------------------------------------------------------------------
# Actor Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (distribution): GaussianDistribution()
#   (mlp): MLP(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# Critic Model: MLPModel(
#   (obs_normalizer): EmpiricalNormalization()
#   (mlp): MLP(
#     (0): Linear(in_features=4, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Linear(in_features=256, out_features=128, bias=True)
#     (3): ELU(alpha=1.0)
#     (4): Linear(in_features=128, out_features=64, bias=True)
#     (5): ELU(alpha=1.0)
#     (6): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# ╭────── viser (listening *:8080) ───────╮
#
# ==================================
# ✅ Server is running on port 8080!
# ==================================

# %% [markdown]
# ### **🖥️ Embed Client as iframe**

# %%
from google.colab import output

port = detected_port if detected_port else 8081
output.serve_kernel_port_as_iframe(port=port, height=700)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 port = detected_port if detected_port else 8081
# ----> 2 ipynb.serve_kernel_port_as_iframe(port=port, height=700)
#
# NameError: name 'ipynb' is not defined
